# %% [markdown]
# ## Reading srt file in Python

# %% [markdown]
# --------
# ### It's just like reading normal text files, FYI Fact: SRT full form: Sub Rip Text

# %%
lineList = []

# read file line by line
file = open( "/home/sachin/AthenasOwl/DeepLearningUtility/DeepLearningUtility/Data/srt/Bohemian_rhapsody.srt")
lines = file.readlines()
file.close()

# look for patterns and parse

# Remove blank lines from file
lines = [i for i in lines if i[:-1]]

# %%
lines
# Out:
# ['\ufeff0\n',
#  '00:00:00,000 --> 00:00:00,000\n',
#  'By\xa0RentAnAdviser.com\n',
#  '1\n',
#  '00:00:11,403 --> 00:00:18,302\n',
#  'Is\xa0this\xa0the\xa0real\xa0life?\n',
#  'Is\xa0this\xa0just\xa0fantasy?\n',
#  '2\n',
#  '00:00:18,408 --> 00:00:25,807\n',
#  'Caught\xa0in\xa0a\xa0landslide‚\xa0no\n',
#  'escape\xa0from\xa0reality\n',
#  '3\n',
#  '00:00:25,915 --> 00:00:35,314\n',
#  'Open\xa0your\xa0eyes‚\xa0look\xa0up\n',
#  'to\xa0the\xa0skies\xa0and\xa0see\n',
#  '4\n',
#  '00:00:36,210 --> 00:00:42,059\n',
#  'I\xa0am\xa0just\xa0a\xa0poor\xa0boy‚\n',
#  'I\xa0need\xa0no\xa0sympathy\n',
#  '5\n',
#  '00:00:42,113 --> 00:00:49,312\n',
#  'Because\xa0I\xa0am\xa0easy\xa0come‚\xa0easy\n',
#  'go‚\xa0little\xa0high‚\xa0little\xa0low\n',
#  '6\n',
#  '00:00:49,416 --> 00:01:03,215\n',
#  'Any\xa0way\xa0the\xa0wind\xa0blows\xa0doesn′t\n',
#  'really\xa0matter\xa0to\xa0me‚\xa0to\xa0me\n',
#  '7\n',
#  '00:01:06,515 --> 00:01:11,914\n',
#  'Mama‚\xa0just\xa0killed\xa0a\xa0man\n',
# ...
